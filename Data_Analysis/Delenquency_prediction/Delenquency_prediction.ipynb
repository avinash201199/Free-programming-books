# %%
pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv('Delinquency_dataset.csv')
df.head(10)
# Out:
#   Customer_ID  Age    Income  Credit_Score  Credit_Utilization  \
# 0    CUST0001   56  165580.0         398.0            0.390502
# 1    CUST0002   69  100999.0         493.0            0.312444
# 2    CUST0003   46  188416.0         500.0            0.359930
# 3    CUST0004   32  101672.0         413.0            0.371400
# 4    CUST0005   60   38524.0         487.0            0.234716
# 5    CUST0006   25   84042.0         700.0            0.650540
# 6    CUST0007   38   35056.0         354.0            0.390581
# 7    CUST0008   56  123215.0         415.0            0.532715
# 8    CUST0009   36   66991.0         405.0            0.413035
# 9    CUST0010   40   34870.0         679.0            0.361824
#
#    Missed_Payments  Delinquent_Account  Loan_Balance  Debt_to_Income_Ratio  \
# 0                3                   0       16310.0              0.317396
# 1                6                   1       17401.0              0.196093
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 461 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer_ID           461 non-null    object
#  1   Age                   461 non-null    int64
#  2   Income                461 non-null    float64
#  3   Credit_Score          460 non-null    float64
#  4   Credit_Utilization    461 non-null    float64
#  5   Missed_Payments       461 non-null    int64
#  6   Delinquent_Account    461 non-null    int64
#  7   Loan_Balance          461 non-null    float64
#  8   Debt_to_Income_Ratio  461 non-null    float64
#  9   Employment_Status     461 non-null    object
#  10  Account_Tenure        461 non-null    int64
#  11  Credit_Card_Type      461 non-null    object
#  12  Location              461 non-null    object
#  13  Month_1               461 non-null    object
#  14  Month_2               461 non-null    object
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Income                  39
# Credit_Score             2
# Credit_Utilization       0
# Missed_Payments          0
# Delinquent_Account       0
# Loan_Balance            29
# Debt_to_Income_Ratio     0
# Employment_Status        0
# Account_Tenure           0
# Credit_Card_Type         0
# Location                 0
# Month_1                  0
# Month_2                  0
# Month_3                  0
# Month_4                  0
# Month_5                  0
# Month_6                  0
# dtype: int64

# %%
df = df.dropna(subset=['Income'])

# %% [markdown]
# droped the rows in which the income value is null

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Income                   0
# Credit_Score             1
# Credit_Utilization       0
# Missed_Payments          0
# Delinquent_Account       0
# Loan_Balance            25
# Debt_to_Income_Ratio     0
# Employment_Status        0
# Account_Tenure           0
# Credit_Card_Type         0
# Location                 0
# Month_1                  0
# Month_2                  0
# Month_3                  0
# Month_4                  0
# Month_5                  0
# Month_6                  0
# dtype: int64

# %%
df.describe()
# Out:
#               Age         Income  Credit_Score  Credit_Utilization  \
# count  461.000000     461.000000    460.000000          461.000000
# mean    46.121475  108379.893709    576.167391            0.488305
# std     16.118393   53662.723741    168.756881            0.194645
# min     18.000000   15404.000000    301.000000            0.050000
# 25%     33.000000   62295.000000    415.000000            0.356435
# 50%     46.000000  107658.000000    584.000000            0.481179
# 75%     59.000000  155734.000000    725.000000            0.630038
# max     74.000000  199943.000000    847.000000            1.025843
#
#        Missed_Payments  Delinquent_Account  Loan_Balance  \
# count       461.000000          461.000000    436.000000
# mean          2.941432            0.162690  48671.516055
# std           1.953491            0.369483  29577.310153
# min           0.000000            0.000000    612.000000
# 25%           1.000000            0.000000  23354.500000
# ...

# %%
for i in df['Loan_Balance']:
    if i=='NaN':
        i=48671.51

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Income                  39
# Credit_Score             2
# Credit_Utilization       0
# Missed_Payments          0
# Delinquent_Account       0
# Loan_Balance            29
# Debt_to_Income_Ratio     0
# Employment_Status        0
# Account_Tenure           0
# Credit_Card_Type         0
# Location                 0
# Month_1                  0
# Month_2                  0
# Month_3                  0
# Month_4                  0
# Month_5                  0
# Month_6                  0
# dtype: int64
